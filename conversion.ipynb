# %%
print("""
Conversion Menu
1. Hours → Seconds
2. Kilograms → Pounds
3. Miles → Kilometers
4. Celsius ↔ Fahrenheit
""")

choice = int(input("Enter your choice: "))

match choice:
    case 1:
        a = float(input("Enter Hours: "))
        b = a * 60 * 60
        print(f"{a} Hours = {b} Seconds")

    case 2:
        a = float(input("Enter Kilograms: "))
        b = a * 2.21
        print(f"{a} Kilograms = {b} Pounds")

    case 3:
        a = float(input("Enter Miles: "))
        b = a * 1.61
        print(f"{a} Miles = {b} Kilometers")

    case 4:
        c = float(input("Enter Temperature in Celsius: "))
        f = float(input("Enter Temperature in Fahrenheit: "))

        fahrenheit = (c * 1.8) + 32
        celsius = (f - 32) * 5/9

        print("Temperature in Fahrenheit which is given in celcius", fahrenheit)
        print("Temperature in Celsius which is given in fahrenheit:", celsius)

    case _:
        print("Invalid choice!")
# Out:
# Conversion Menu
# 1. Hours → Seconds
# 2. Kilograms → Pounds
# 3. Miles → Kilometers
# 4. Celsius ↔ Fahrenheit
# Enter your choice:  1
# Enter Hours:  4
# 4.0 Hours = 14400.0 Seconds
