# %%
print("welcome to movie ticket booking")

name = input("enter your name:")
age = int(input("enter your age:"))
tickets = int(input("enter number of tickets for booking:"))

if age < 15:
    price = 100   
    print("child ticket price is 100 per ticket")

elif age >= 15 and age < 60:
    price = 250   
    print("adult ticket price is 150 per ticket")

else:
    price = 120  
    print("senior ticket price is 120 per ticket")

total = tickets * price

print("hello", name)
print("you booked", tickets, "tickets")
print("your total amount is", total)
# Out:
# welcome to movie ticket booking
# enter your name: anjali
# enter your age: 20
# enter number of tickets for booking: 5
# adult ticket price is 150 per ticket
# hello anjali
# you booked 5 tickets
# your total amount is 1250
