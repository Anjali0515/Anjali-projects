# %%
num = float(input("enter a number to find is it negative or positive:"))

if num > 0:
    print(num, "this no. is a positive")

elif num < 0:
    print(num, "it is a negative")

else:
    print("number is zero")
# Out:
# enter a number to find is it negative or positive: 67
# 67.0 this no. is a positive
